# %%
# %matplotlib inline
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

from pandas import set_option
set_option("display.max_rows", 16)

LARGE_FIGSIZE = (12, 8)

# %%
cd data
# Out:
# /Users/esteban/unm/MachineLearning/Project1/data

# %%
ls
# Out:
# testing.txt     training.txt    validation.txt

# %%
testing_data = pd.read_table("testing.txt")
testing_data
# Out:
#       e,x,s,n,f,n,a,c,b,o,e,?,s,s,o,o,p,n,o,p,y,v,l
# 0     e,f,y,n,t,n,f,c,b,w,t,b,s,s,g,w,p,w,o,p,n,v,d
# 1     p,f,y,g,f,f,f,c,b,g,e,b,k,k,n,n,p,w,o,l,h,v,d
# 2     e,x,s,w,t,a,f,c,b,k,e,c,s,s,w,w,p,w,o,p,n,n,m
# 3     e,f,y,u,f,n,f,c,n,h,e,?,s,f,w,w,p,w,o,f,h,v,d
# 4     e,k,f,c,f,n,f,w,n,w,e,b,f,f,w,n,p,w,o,e,w,v,l
# 5     e,f,s,w,f,n,f,w,b,h,t,e,f,s,w,w,p,w,o,e,k,a,g
# 6     e,f,y,n,t,n,f,c,b,p,t,b,s,s,g,w,p,w,o,p,n,y,d
# 7     p,f,f,y,f,f,f,c,b,h,e,b,k,k,b,b,p,w,o,l,h,y,p
# ...                                             ...
# 2022  e,x,s,g,f,n,f,w,b,h,t,e,f,s,w,w,p,w,o,e,n,s,g
# 2023  p,b,f,n,f,n,f,c,n,w,e,?,k,y,w,n,p,w,o,e,w,v,d
# 2024  e,x,y,n,t,n,f,c,b,n,t,b,s,s,p,p,p,w,o,p,n,v,d
# 2025  p,x,s,g,t,f,f,c,b,w,t,b,s,f,w,w,p,w,o,p,h,v,u
# 2026  e,f,s,g,f,n,f,w,b,h,t,e,s,s,w,w,p,w,o,e,k,s,g
# 2027  e,x,s,g,f,n,f,w,b,h,t,e,f,f,w,w,p,w,o,e,k,a,g
# 2028  p,x,f,p,f,c,f,w,n,u,e,b,s,s,w,w,p,w,o,p,n,s,d
# 2029  p,f,y,n,f,y,f,c,n,b,t,?,k,s,p,p,p,w,o,e,w,v,l
#
# [2030 rows x 1 columns]

# %%
testing_data = pd.read_table("testing.txt", sep=",", names=["label","cap-shape","cap-surface","cap-color","bruises","oder",
                                                  "gill-attachment","gill-spacing","gill-size","gill-color","gill-shape",
                                                  "stalk-root","stalk-surface-above-ring","stalk-surface-below-ring",
                                                  "stalk-color-above-ring","stalk-color-below-ring","veil-type",
                                                  "veil-color","ring-number","ring-type","spore-print-color",
                                                  "population","habitat"])
testing_data
# Out:
#      label cap-shape cap-surface cap-color bruises oder gill-attachment  \
# 0        e         x           s         n       f    n               a
# 1        e         f           y         n       t    n               f
# 2        p         f           y         g       f    f               f
# 3        e         x           s         w       t    a               f
# 4        e         f           y         u       f    n               f
# 5        e         k           f         c       f    n               f
# 6        e         f           s         w       f    n               f
# 7        e         f           y         n       t    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 2023     e         x           s         g       f    n               f
# 2024     p         b           f         n       f    n               f
# 2025     e         x           y         n       t    n               f
# 2026     p         x           s         g       t    f               f
# 2027     e         f           s         g       f    n               f
# 2028     e         x           s         g       f    n               f
# 2029     p         x           f         p       f    c               f
# 2030     p         f           y         n       f    y               f
#
#      gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0               c         b          o   ...                          s
# 1               c         b          w   ...                          s
# 2               c         b          g   ...                          k
# 3               c         b          k   ...                          s
# 4               c         n          h   ...                          f
# 5               w         n          w   ...                          f
# 6               w         b          h   ...                          s
# 7               c         b          p   ...                          s
# ...           ...       ...        ...   ...                        ...
# 2023            w         b          h   ...                          s
# 2024            c         n          w   ...                          y
# 2025            c         b          n   ...                          s
# 2026            c         b          w   ...                          f
# 2027            w         b          h   ...                          s
# 2028            w         b          h   ...                          f
# 2029            w         n          u   ...                          s
# 2030            c         n          b   ...                          s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         o                      o         p          n
# 1                         g                      w         p          w
# 2                         n                      n         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# 5                         w                      n         p          w
# 6                         w                      w         p          w
# 7                         g                      w         p          w
# ...                     ...                    ...       ...        ...
# 2023                      w                      w         p          w
# 2024                      w                      n         p          w
# 2025                      p                      p         p          w
# 2026                      w                      w         p          w
# 2027                      w                      w         p          w
# 2028                      w                      w         p          w
# 2029                      w                      w         p          w
# 2030                      p                      p         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 y          v       l
# 1              o         p                 n          v       d
# 2              o         l                 h          v       d
# 3              o         p                 n          n       m
# 4              o         f                 h          v       d
# 5              o         e                 w          v       l
# 6              o         e                 k          a       g
# 7              o         p                 n          y       d
# ...          ...       ...               ...        ...     ...
# 2023           o         e                 n          s       g
# 2024           o         e                 w          v       d
# 2025           o         p                 n          v       d
# 2026           o         p                 h          v       u
# 2027           o         e                 k          s       g
# 2028           o         e                 k          a       g
# 2029           o         p                 n          s       d
# 2030           o         e                 w          v       l
#
# [2031 rows x 23 columns]
